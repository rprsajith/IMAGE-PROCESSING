# %%
import cv2
#cv2 - computer vision2

# %%
img = cv2.imread('/content/virat kohli 1.jpg')
print(img)
# Out:
# [[[ 96  95  91]
#   [ 97  96  92]
#   [ 98  97  93]
#   ...
#   [ 51  48  57]
#   [ 52  48  59]
#   [ 49  45  56]]
#
#  [[ 99  98  94]
#   [ 99  98  94]
#   [ 99  98  94]
#   ...
#   [ 52  49  58]
#   [ 54  50  61]
#   [ 53  49  60]]
#
#  [[101 100  96]
#   [101 100  96]
#   [100  99  95]
#   ...
#   [ 52  49  58]
#   [ 55  51  62]
#   [ 57  53  64]]
#
#  ...
#
#  [[121  57  39]
#   [121  57  39]
#   [120  56  38]
#   ...
#   [117  58  43]
#   [116  57  42]
#   [115  56  41]]
#
#  [[121  57  39]
#   [121  57  39]
#   [120  56  38]
#   ...
#   [118  57  43]
#   [117  56  42]
#   [116  55  41]]
#
#  [[122  58  40]
#   [121  57  39]
#   [120  56  38]
#   ...
#   [118  57  43]
#   [117  56  42]
#   [116  55  41]]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1088>

# %%
img1=cv2.imread('/content/virat kohli 2.jpg',0)
#Adding a 0 the picture was changing black and white spot the difference between first and second image copy path

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=524x654>
